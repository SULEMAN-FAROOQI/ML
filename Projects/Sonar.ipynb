# %% [markdown]
# This code represnets an example of a ML workflow. It predicts whether the submarine encounters a rock or a mine based on sonar signals and other parameters.

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("C:\\Users\\sulem\\Desktop\\Codes\\ML\\Datasets\\sonar data.csv", header = None)
df = df.rename(columns={60: "Target"})
new_col = [f"x{i+1}" for i in range(60)]
new_col.append("Target")
df.columns = new_col

df.head()
# Out:
#        x1      x2      x3      x4      x5      x6      x7      x8      x9     x10     x11     x12     x13     x14     x15     x16     x17     x18     x19     x20     x21     x22     x23     x24     x25     x26     x27     x28     x29     x30     x31     x32     x33     x34     x35     x36     x37     x38     x39     x40     x41     x42     x43     x44     x45     x46     x47     x48     x49     x50     x51     x52     x53     x54     x55     x56     x57     x58     x59     x60 Target
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  0.2111  0.1609  0.1582  0.2238  0.0645  0.0660  0.2273  0.3100  0.2999  0.5078  0.4797  0.5783  0.5071  0.4328  0.5550  0.6711  0.6415  0.7104  0.8080  0.6791  0.3857  0.1307  0.2604  0.5121  0.7547  0.8537  0.8507  0.6692  0.6097  0.4943  0.2744  0.0510  0.2834  0.2825  0.4256  0.2641  0.1386  0.1051  0.1343  0.0383  0.0324  0.0232  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  0.0090  0.0032      R
# ...

# %%
pd.set_option('display.max_rows', None)
print(df.isna().sum())
print(df["Target"].value_counts())
# Out:
# x1        0
# x2        0
# x3        0
# x4        0
# x5        0
# x6        0
# x7        0
# x8        0
# x9        0
# x10       0
# x11       0
# x12       0
# x13       0
# x14       0
# x15       0
# x16       0
# x17       0
# x18       0
# x19       0
# x20       0
# x21       0
# x22       0
# x23       0
# x24       0
# x25       0
# x26       0
# x27       0
# x28       0
# x29       0
# x30       0
# x31       0
# x32       0
# x33       0
# x34       0
# x35       0
# x36       0
# x37       0
# x38       0
# x39       0
# x40       0
# x41       0
# x42       0
# x43       0
# x44       0
# x45       0
# x46       0
# x47       0
# x48       0
# x49       0
# x50       0
# x51       0
# x52       0
# x53       0
# x54       0
# x55       0
# x56       0
# x57       0
# x58       0
# x59       0
# x60       0
# Target    0
# dtype: int64
# Target
# M    111
# R     97
# Name: count, dtype: int64

# %% [markdown]
# M = Mine
# R = Rock

# %%
df.describe()
# Out:
#                x1          x2          x3          x4          x5          x6          x7          x8          x9         x10         x11         x12         x13         x14         x15         x16         x17         x18         x19         x20         x21         x22         x23         x24         x25         x26         x27         x28         x29         x30         x31         x32         x33         x34         x35         x36         x37         x38         x39         x40         x41         x42         x43         x44         x45         x46         x47         x48         x49         x50         x51         x52         x53         x54         x55         x56         x57         x58         x59         x60
# ...

# %%
x = df.drop("Target", axis = 1)
y = df["Target"]

# %%
scaler = StandardScaler()
x = scaler.fit_transform(x)

encoder = LabelEncoder()
y = encoder.fit_transform(y)
print(pd.Series(y).value_counts())

trainx , testx , trainy, testy = train_test_split(x, y, test_size=0.3, stratify=y, random_state=33)
# Out:
# 0    111
# 1     97
# Name: count, dtype: int64

# %%
log = LogisticRegression(solver = "saga", max_iter=1000)

log.fit(trainx,trainy)
predy_log = log.predict(testx)
print("The Accuracy Score after using Logistic Regression is:", accuracy_score(testy,predy_log))
# Out:
# The Accuracy Score after using Logistic Regression is: 0.8571428571428571

# %% [markdown]
# Testing on new Data (First line of the dataframe):

# %%
import warnings
warnings.filterwarnings('ignore')

data = [
    0.0200, 0.0371, 0.0428, 0.0207, 0.0954, 0.0986, 0.1539, 0.1601, 0.3109, 0.2111,
    0.1609, 0.1582, 0.2238, 0.0645, 0.0660, 0.2273, 0.3100, 0.2999, 0.5078, 0.4797,
    0.5783, 0.5071, 0.4328, 0.5550, 0.6711, 0.6415, 0.7104, 0.8080, 0.6791, 0.3857,
    0.1307, 0.2604, 0.5121, 0.7547, 0.8537, 0.8507, 0.6692, 0.6097, 0.4943, 0.2744,
    0.0510, 0.2834, 0.2825, 0.4256, 0.2641, 0.1386, 0.1051, 0.1343, 0.0383, 0.0324,
    0.0232, 0.0027, 0.0065, 0.0159, 0.0072, 0.0167, 0.0180, 0.0084, 0.0090, 0.0032
]

column_names = [f"x{i+1}" for i in range(60)]

new_data = pd.DataFrame([dict(zip(column_names, data))])

prediction = log.predict(new_data)

result = "Mine" if prediction[0] == '0' else "Rock"
print("Prediction:", result)
# Out:
# Prediction: Rock
